# %% [markdown]
# ## Aula matplotlib

# %%
pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.9 kB 667.8 kB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 3.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as shs


x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x,y,color="red")
plt.xlabel("Variaveis X")
plt.ylabel("Variaveis Y")
plt.title("Grafico Fds")
plt.show()

# %%
categorias=["a","b","c","d"]
valores = [10,20,30,40]
plt.bar(categorias, valores)
plt.show()

# %%
dados = np.random.randn(10001)
plt.hist(dados,bins=20, edgecolor="white")
plt.show()

# %%
dados = [7,8,9,10,11,12,50]
plt.boxplot(dados)
plt.show()

# %%
import seaborn as shs

dias = ["seg","terca", "quarta", "quinta", "sexta","sabado","domingo"]
horas = ["manha","tarde","noite","madrugada","almoco","happy hour"]
vendas = np.random.randint(0,50,(7,6))

plt.figure(figsize=(8,5))
shs.heatmap(vendas, annot= True, cmap="coolwarm", xticklabels=horas, yticklabels=dias)
plt.title("Heatmap")
pltxlabel("periodo da semana")
pltylabel("dias da semana")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 10
#       8 shs.heatmap(vendas, annot= True, cmap="coolwarm", xticklabels=horas, yticklabels=dias)
#       9 plt.title("Heatmap")
# ---> 10 pltxlabel("periodo da semana")
#      11 pltylabel("dias da semana")
#      12 plt.show()
#
# NameError: name 'pltxlabel' is not defined

# %%
x = [1,2,3,4,5]
y = [10,20,25,30,40]
plt.plot(x, y, color="red", linestyle="-", marker="s", label="Série de dados")
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.legend()
plt.grid(True)
plt.show()
